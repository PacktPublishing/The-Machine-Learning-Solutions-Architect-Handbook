# %% [markdown]
# ## This notebook demonstrates the various Textract APIs

# %%
from pprint import pprint
import boto3

document_file_name = 'data/textract_sample.png'
with open(document_file_name, 'rb') as document_file:
                document_bytes = document_file.read()
        
textract_client = boto3.client('textract')

# %%
print('Detecting tables and forms')
feature_types = ['TABLES', 'FORMS']
tables_forms = textract_client.analyze_document(
        Document={'Bytes': document_bytes}, FeatureTypes=feature_types)
blocks_to_show = 10
pprint(tables_forms['Blocks'][:blocks_to_show])
# Out:
# Detecting tables and forms
# [{'BlockType': 'PAGE',
#   'Geometry': {'BoundingBox': {'Height': 0.9991273880004883,
#                                'Left': 0.0,
#                                'Top': 0.0,
#                                'Width': 1.0},
#                'Polygon': [{'X': 6.721481060426241e-17, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 0.9991273880004883},
#                            {'X': 0.0, 'Y': 0.9991273880004883}]},
#   'Id': 'ebd68a09-0dfe-4937-9d0c-a0264ceb5183',
#   'Relationships': [{'Ids': ['892b4c4f-2422-4c68-a742-7253a4c6cf4d',
#                              '1e689083-bb28-4eaa-80dc-7182332f0957',
#                              'f77bded9-539c-404e-bfdd-0917de2c63e4',
#                              'e310de3e-6694-425d-ab03-1a83b33c431e',
#                              '2ad8a28f-aee6-4670-bc7e-75ea8e68092f',
#                              'b2a958e0-8843-4bce-a074-145cccc03905',
#                              '35dfce91-4cb9-49f9-835e-f59d11f0391d',
#                              'b079bedc-49b8-4fa8-bdd8-69ae3bf6b3bc',
#                              'df247dee-0230-4fe4-a93f-97d11b0d0e37',
#                              '0967776e-9a10-48fa-805d-3a07e3d526cd',
#                              '0cb4a08b-32d5-4884-84df-2e17c912a8fa',
#                              'e6eb6727-b3c2-4906-a518-4a54099f9473',
#                              '6a5fe257-d13b-4c05-aa84-2f0e48260001',
#                              'faeae984-0519-4923-a4ce-c3e6b1ac29f5',
#                              '951958b6-7606-4a8f-9ab1-995b9819093e',
#                              '4a53c2e2-92ef-4ee9-982f-3e7948029a85',
#                              '7c757f26-3552-4ade-aaf2-c4bc53bf17f4',
#                              '10310e36-8732-468f-805c-fd26160a2b70',
#                              '2dfdbbbc-6e7b-4189-94d7-f2d79c110db8',
#                              '0cfe5c02-62ce-402d-b619-32d6811f3ac8',
#                              'a0e5497c-5c13-4969-98f4-a9ef7ad5e7ba',
#                              '3d1a37ae-0e93-4c7f-9130-ca2089d44405',
#                              '304b38db-4e8d-4e2d-ba38-2018d2d2e562',
#                              '5ef54e57-3523-4011-bddf-1b17d78f49c1',
#                              'c4bd15c0-f4db-457d-910b-b97c274a0b16',
#                              '856c4c02-9f8f-46f7-add3-d7f2ddf52778',
#                              '14f29b4e-f74a-4295-b3b9-4a428f3f2fa2',
#                              'c8addd52-d278-4582-a8a5-31c220bf5957',
#                              'b18e205d-86a6-403d-82be-36f1303e9983',
#                              'daab5239-9833-4915-9110-848209e17b3d',
#                              '72e6029a-d808-4765-a993-e6ccc670bf71',
#                              '6ab156ee-00ab-4128-af86-538310dcb9ca',
#                              '79d0afd6-898f-4667-b5d7-56de9ec335de',
#                              '1746e5b5-cf51-4165-ad9f-c5aa6ac35cba',
#                              '8d84ee8e-8d1f-429f-9d5b-3fd702a0e001',
#                              '2dd41cb6-b3f1-411f-9131-3f093172caf3',
#                              'c8d43174-41ee-4f6f-b1bb-4288d211ad3e',
#                              'd3760104-a81f-4d1c-b511-9ca3a0489204',
#                              '3bab191e-f54d-4b62-bafa-41769fee1f31',
#                              '6c296ba5-184d-4e70-987e-0f6ffa8312e7',
#                              '1288cd9a-7924-4d69-a559-5d45628444e0',
#                              '42aa7734-0a93-4e6c-a99f-98e5318ac82f',
#                              '2abb908e-2098-494b-a36f-1390e9aac656',
#                              '7cbb042e-0bfd-43b7-8f93-c66a9b92a392',
#                              'b5f634a4-146d-46cc-9395-6c8d37a53d74',
#                              'e59f614f-30fb-4c47-868f-066711ea7cac',
#                              'dc63e691-5a52-4a94-a47c-ea9ac26b1ceb',
#                              '38d844da-3e4f-41e5-bd15-cd88ae95fb2a',
#                              '25722821-fe50-4d2f-b622-9831ce3efea4',
#                              '73c8d9b6-ca85-4ab1-8aa4-133d52496878',
#                              '4687c811-3988-42a2-96d4-7011b4a0fcca',
#                              '1a459ddd-7309-43d8-b260-bde6e9fdb9a9',
#                              '52dd2d3b-552b-4055-8be2-865c64b320f0',
#                              '1399077a-35ed-4d5a-b1f1-bc030ca3c147',
#                              '563cc365-2734-4550-a385-daea438c3a6a',
#                              '88de5041-4d78-4161-8f96-34c4a67e1116',
#                              '046bcdd4-c76e-4c1c-a445-104d257366d0',
#                              '6e90c15f-d63f-4049-b68b-dcaa5bcd4938',
#                              '6cf905ff-8aef-41f7-be3e-f47dd1143ff2',
#                              '20ff7705-96af-41be-b6c0-6599b806b2cf',
#                              'b2df50bb-0405-408d-bf00-80ec0855553e',
#                              '9eeb3fd5-b408-4b20-8466-f75539387fc7',
#                              'b07b23c4-5c11-4d6c-b545-1a2c3c6720ef',
#                              '3f010ddf-15ca-417f-9399-4f5742f6fe18',
#                              '3d5cc944-c537-4419-86e3-fd138ecc2a26',
#                              'd183a64b-b69c-475e-a35d-f152703ee1c0',
#                              'f0b0c9b8-85d9-45c7-92b7-884553265072',
#                              '7a337cc8-b13a-4af6-9958-9d807fb5929d',
#                              '026e9961-47b6-4129-8964-2e4de0c5954d',
#                              'cc5bc3af-f43f-4821-aa2f-87cd6c6cf157',
#                              'd5d5c9a3-bf3b-48b1-b76b-2e3167a39c83',
#                              'c1937a98-50c8-48cd-a65c-47f474a67c8f',
#                              '5cbf1324-89ad-474d-9912-19a86f59b81a',
#                              'f11608c2-4c45-4f6f-aa3b-891647c5770f',
#                              '6500187f-b6dd-4e4d-8efc-bc1ee5fe3ea9',
#                              '7b45d8d5-9dc1-44bd-9857-c556b20b44dd',
#                              '8ab2c4be-c022-4aab-87c9-c3abf34f15cf',
#                              '442eb3fe-2936-40eb-ba71-20bcb18569c6',
#                              'd59a9376-390f-48dd-bf19-23a9a310e890',
#                              'c1b23513-d84d-40a4-849a-195978eae395',
#                              'e3fec6a8-9443-4d52-966c-38576b177de1',
#                              '66f1db29-e34c-4479-8451-f65980f43e50',
#                              '71dec7df-a2ce-446a-8585-107358c05e15',
#                              '52b93ff8-0744-4ba0-ad7d-7258d731fe8a',
#                              'ca32a20a-29d6-41c2-ab99-2a42b7fb76ca',
#                              'e33fc75b-0f2e-4b8f-ab67-41ec33fdd004',
#                              'e63fd4c3-4d96-423e-b6f9-57cb342e23a5',
#                              '823c42cd-bc23-41de-a742-90c566e3ee43',
#                              'f26ea9ed-1359-4aa8-b8d6-3125604f5129'],
#                      'Type': 'CHILD'}]},
#  {'BlockType': 'LINE',
#   'Confidence': 99.65342712402344,
#   'Geometry': {'BoundingBox': {'Height': 0.033739473670721054,
#                                'Left': 0.022331932559609413,
#                                'Top': 0.03292882815003395,
#                                'Width': 0.1913457214832306},
#                'Polygon': [{'X': 0.022331932559609413,
#                             'Y': 0.03292882815003395},
#                            {'X': 0.21367764472961426, 'Y': 0.03292882815003395},
#                            {'X': 0.21367764472961426, 'Y': 0.066668301820755},
#                            {'X': 0.022331932559609413,
#                             'Y': 0.066668301820755}]},
#   'Id': '892b4c4f-2422-4c68-a742-7253a4c6cf4d',
#   'Relationships': [{'Ids': ['10809793-10e0-4548-9b5f-a5081b18be9e',
#                              '32ea3d56-616d-490a-b53c-a24a71a256e1',
#                              'b281ad24-ac47-4131-8082-d72ce7af4078'],
#                      'Type': 'CHILD'}],
#   'Text': 'ABC Company 51-2322286'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.84576416015625,
#   'Geometry': {'BoundingBox': {'Height': 0.04118376970291138,
#                                'Left': 0.7817816734313965,
#                                'Top': 0.048711709678173065,
#                                'Width': 0.19723160564899445},
#                'Polygon': [{'X': 0.7817816734313965, 'Y': 0.048711709678173065},
#                            {'X': 0.9790132641792297, 'Y': 0.048711709678173065},
#                            {'X': 0.9790132641792297, 'Y': 0.08989547938108444},
#                            {'X': 0.7817816734313965,
#                             'Y': 0.08989547938108444}]},
#   'Id': '1e689083-bb28-4eaa-80dc-7182332f0957',
#   'Relationships': [{'Ids': ['9ac51757-eb54-42d2-9494-ba419c21ffcf',
#                              '4bbd64dd-c3ab-4289-a3c2-b206c152fcee'],
#                      'Type': 'CHILD'}],
#   'Text': 'Earnings Statement'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.57268524169922,
#   'Geometry': {'BoundingBox': {'Height': 0.027046622708439827,
#                                'Left': 0.023824844509363174,
#                                'Top': 0.08138158172369003,
#                                'Width': 0.10612806677818298},
#                'Polygon': [{'X': 0.023824844509363174,
#                             'Y': 0.08138158172369003},
#                            {'X': 0.12995290756225586, 'Y': 0.08138158172369003},
#                            {'X': 0.12995290756225586, 'Y': 0.10842820256948471},
#                            {'X': 0.023824844509363174,
#                             'Y': 0.10842820256948471}]},
#   'Id': 'f77bded9-539c-404e-bfdd-0917de2c63e4',
#   'Relationships': [{'Ids': ['2f6a07be-2094-44c3-96d0-fb5a3cf23539',
#                              'b7b65e4a-b418-456a-bda2-9ba635b4f63c',
#                              '80c80d65-ac6d-4d92-b1aa-e35cbd175eea'],
#                      'Type': 'CHILD'}],
#   'Text': '123 Main Street,'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.65360260009766,
#   'Geometry': {'BoundingBox': {'Height': 0.02967524155974388,
#                                'Left': 0.02264290302991867,
#                                'Top': 0.11935323476791382,
#                                'Width': 0.13358129560947418},
#                'Polygon': [{'X': 0.02264290302991867, 'Y': 0.11935323476791382},
#                            {'X': 0.15622420608997345, 'Y': 0.11935323476791382},
#                            {'X': 0.15622420608997345, 'Y': 0.149028480052948},
#                            {'X': 0.02264290302991867, 'Y': 0.149028480052948}]},
#   'Id': 'e310de3e-6694-425d-ab03-1a83b33c431e',
#   'Relationships': [{'Ids': ['be3a2e1b-502f-4fcb-bafe-0c75ec8bcb95',
#                              '3318ff6a-8fb2-4ff2-8a03-09a359b45dad',
#                              '5cdedd0e-ddc5-4cb1-b9d3-27c79a4e10aa'],
#                      'Type': 'CHILD'}],
#   'Text': 'Anytown, NY 10000.'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.64519500732422,
#   'Geometry': {'BoundingBox': {'Height': 0.02517203614115715,
#                                'Left': 0.8593630790710449,
#                                'Top': 0.10847170650959015,
#                                'Width': 0.12165312469005585},
#                'Polygon': [{'X': 0.8593630790710449, 'Y': 0.10847170650959015},
#                            {'X': 0.981016218662262, 'Y': 0.10847170650959015},
#                            {'X': 0.981016218662262, 'Y': 0.1336437463760376},
#                            {'X': 0.8593630790710449, 'Y': 0.1336437463760376}]},
#   'Id': '2ad8a28f-aee6-4670-bc7e-75ea8e68092f',
#   'Relationships': [{'Ids': ['3901734d-3f96-4696-9953-c5b4455cde33',
#                              'd9fa930f-3b05-4fdb-9ea3-87841544d28e',
#                              'd9c9e2f8-2ac9-4e1b-b98b-82498f03f94c'],
#                      'Type': 'CHILD'}],
#   'Text': 'Stub Number: 245'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.4002456665039,
#   'Geometry': {'BoundingBox': {'Height': 0.030905451625585556,
#                                'Left': 0.03681860864162445,
#                                'Top': 0.21018506586551666,
#                                'Width': 0.09910108149051666},
#                'Polygon': [{'X': 0.03681860864162445, 'Y': 0.21018506586551666},
#                            {'X': 0.1359196901321411, 'Y': 0.21018506586551666},
#                            {'X': 0.1359196901321411, 'Y': 0.24109052121639252},
#                            {'X': 0.03681860864162445,
#                             'Y': 0.24109052121639252}]},
#   'Id': 'b2a958e0-8843-4bce-a074-145cccc03905',
#   'Relationships': [{'Ids': ['58435e19-0fc7-4b41-823c-0acdc56e3736',
#                              'a6f2b58d-a5c9-4fd5-9cd5-612c974620b3'],
#                      'Type': 'CHILD'}],
#   'Text': 'Employee Info'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.91171264648438,
#   'Geometry': {'BoundingBox': {'Height': 0.024226123467087746,
#                                'Left': 0.39753517508506775,
#                                'Top': 0.21044114232063293,
#                                'Width': 0.029711024835705757},
#                'Polygon': [{'X': 0.39753517508506775, 'Y': 0.21044114232063293},
#                            {'X': 0.42724621295928955, 'Y': 0.21044114232063293},
#                            {'X': 0.42724621295928955, 'Y': 0.23466725647449493},
#                            {'X': 0.39753517508506775,
#                             'Y': 0.23466725647449493}]},
#   'Id': '35dfce91-4cb9-49f9-835e-f59d11f0391d',
#   'Relationships': [{'Ids': ['7edb70d3-6324-447e-a32b-9a3ee9f79534'],
#                      'Type': 'CHILD'}],
#   'Text': 'SSN'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.5854263305664,
#   'Geometry': {'BoundingBox': {'Height': 0.030178382992744446,
#                                'Left': 0.4997060000896454,
#                                'Top': 0.20984213054180145,
#                                'Width': 0.09050806611776352},
#                'Polygon': [{'X': 0.4997060000896454, 'Y': 0.20984213054180145},
#                            {'X': 0.5902140736579895, 'Y': 0.20984213054180145},
#                            {'X': 0.5902140736579895, 'Y': 0.2400205135345459},
#                            {'X': 0.4997060000896454, 'Y': 0.2400205135345459}]},
#   'Id': 'b079bedc-49b8-4fa8-bdd8-69ae3bf6b3bc',
#   'Relationships': [{'Ids': ['d141c6ba-8dd2-404a-b4b1-4ea2295d8975',
#                              '8383a786-94a4-41ed-a8c5-55f47d089998'],
#                      'Type': 'CHILD'}],
#   'Text': 'Pay Schedule'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.47364044189453,
#   'Geometry': {'BoundingBox': {'Height': 0.0318121537566185,
#                                'Left': 0.709945023059845,
#                                'Top': 0.20795442163944244,
#                                'Width': 0.07512550801038742},
#                'Polygon': [{'X': 0.709945023059845, 'Y': 0.20795442163944244},
#                            {'X': 0.785070538520813, 'Y': 0.20795442163944244},
#                            {'X': 0.785070538520813, 'Y': 0.23976656794548035},
#                            {'X': 0.709945023059845, 'Y': 0.23976656794548035}]},
#   'Id': 'df247dee-0230-4fe4-a93f-97d11b0d0e37',
#   'Relationships': [{'Ids': ['28c60fb3-d315-46e9-b72c-3ccde492fef0',
#                              'bfac0f6d-1b17-4c0c-9818-9be4f998fc75'],
#                      'Type': 'CHILD'}],
#   'Text': 'Pay Period'}]

# %%
print('Detect text')
text = textract_client.detect_document_text(
        Document={'Bytes': document_bytes})
pprint(text['Blocks']['BlockType'])
# Out:
# Detect text
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2af20cd8e627> in <module>
#       2 text = textract_client.detect_document_text(
#       3         Document={'Bytes': document_bytes})
# ----> 4 pprint(text['Blocks']['BlockType'])
#
# TypeError: list indices must be integers or slices, not str
